# %%
# Análise de Problemas de Qualidade - TechCommerce

import pandas as pd

# Carregando datasets
clientes = pd.read_csv('../data/raw/clientes.csv')
produtos = pd.read_csv('../data/raw/produtos.csv')
vendas = pd.read_csv('../data/raw/vendas.csv')
logistica = pd.read_csv('../data/raw/logistica.csv')

# Exemplo de análise: campos nulos
clientes_nulls = clientes.isnull().mean() * 100
print("Clientes - % de campos nulos:")
print(clientes_nulls)

# Exemplo: emails inválidos
clientes['email_valido'] = clientes['email'].str.contains(r'^[\w\.-]+@[\w\.-]+\.\w+$', na=False)
print("Emails inválidos:", (~clientes['email_valido']).sum())

# Continue com outras dimensões: unicidade, consistência, integridade, etc.
